# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Rough Draft with rough code-through and mistakes
import os 

import numpy as np
import pandas as pd

from glob import glob

import matplotlib.pyplot as plt
#all_imdb_df = pd.read_csv('zippedData')
#for index, row in all_imdb_df.iterrows():
   # if index %1000==0:
    #    print(index)
    #split_words = row['genres'].split()
   # for word in split_words:
      #  if word != "NONE":
      #      all_imdb_df.loc[index, word] = 1
        
       # all_genres = set()
#for genres in joined_df4['genres']:
   # if genres:
       # all_genres.update(genres)

# %%
#imported all the neccesary tools for cleaning

# %%
csv_files = glob("zippedData/*.csv.gz")
csv_files
# Out:
# ['zippedData\\bom.movie_gross.csv.gz',
#  'zippedData\\imdb.name.basics.csv.gz',
#  'zippedData\\imdb.title.akas.csv.gz',
#  'zippedData\\imdb.title.basics.csv.gz',
#  'zippedData\\imdb.title.crew.csv.gz',
#  'zippedData\\imdb.title.principals.csv.gz',
#  'zippedData\\imdb.title.ratings.csv.gz',
#  'zippedData\\tmdb.movies.csv.gz',
#  'zippedData\\tn.movie_budgets.csv.gz']

# %%
# used glob to create a list of the files in the zippedData folder

# %%
csv_files_dict = {}
for filename in csv_files:
    filename_cleaned = os.path.basename(filename).replace(".csv.", "").replace(".", "_").replace("gz", "")
    filename_df = pd.read_csv(filename, index_col=0)
    csv_files_dict[filename_cleaned] = filename_df

# %%
import sqlite3

# %%
df = pd.read_csv("zippedData/imdb.title.crew.csv.gz")
df.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
#used pandas to view a dataframe in the csv.gz folder

# %%
csv_files_dict.keys()
# Out:
# dict_keys(['bom_movie_gross', 'imdb_name_basics', 'imdb_title_akas', 'imdb_title_basics', 'imdb_title_crew', 'imdb_title_principals', 'imdb_title_ratings', 'tmdb_movies', 'tn_movie_budgets'])

# %%
csv_files_dict['bom_movie_gross']
# Out:
#                                                  studio  domestic_gross  \
# title
# Toy Story 3                                          BV     415000000.0
# Alice in Wonderland (2010)                           BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# Inception                                            WB     292600000.0
# Shrek Forever After                                P/DW     238700000.0
# ...                                                 ...             ...
# The Quake                                         Magn.          6200.0
# Edward II (2018 re-release)                          FM          4800.0
# El Pacto                                           Sony          2500.0
# The Swan                                     Synergetic          2400.0
# An Actor Prepares                                 Grav.          1700.0
#
#                                             foreign_gross  year
# title
# ...

# %%
def tableprinter(dict):
    for table in csv_files_dict:
        print(csv_files_dict[table])

# %%
#created a function that printed each table, to help me see which relevant correlations I could use

# %%
tableprinter(csv_files_dict)
# Out:
#                                                  studio  domestic_gross  \
# title
# Toy Story 3                                          BV     415000000.0
# Alice in Wonderland (2010)                           BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# Inception                                            WB     292600000.0
# Shrek Forever After                                P/DW     238700000.0
# ...                                                 ...             ...
# The Quake                                         Magn.          6200.0
# Edward II (2018 re-release)                          FM          4800.0
# El Pacto                                           Sony          2500.0
# The Swan                                     Synergetic          2400.0
# An Actor Prepares                                 Grav.          1700.0
#
#                                             foreign_gross  year
# title
# ...

# %%
csv_files_dict['imdb_name_basics'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 606648 entries, nm0061671 to nm9993380
# Data columns (total 5 columns):
# primary_name          606648 non-null object
# birth_year            82736 non-null float64
# death_year            6783 non-null float64
# primary_profession    555308 non-null object
# known_for_titles      576444 non-null object
# dtypes: float64(2), object(3)
# memory usage: 27.8+ MB

# %%
csv_files_dict['tmdb_movies'].median()
# Out:
# id              309581.000
# popularity           1.374
# vote_average         6.000
# vote_count           5.000
# dtype: float64

# %%
df = csv_files_dict['tn_movie_budgets']

# %%
df
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ..           ...                                          ...
# 78  Dec 31, 2018                                       Red 11
# 79   Apr 2, 1999                                    Following
# 80  Jul 13, 2005                Return to the Land of Wonders
# 81  Sep 29, 2015                         A Plague So Pleasant
# 82   Aug 5, 2005                            My Date With Drew
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# ...

# %%
df = pd.read_csv("zippedData/imdb.title.crew.csv.gz")
df
# Out:
#            tconst                      directors              writers
# 0       tt0285252                      nm0899854            nm0899854
# 1       tt0438973                            NaN  nm0175726,nm1802864
# 2       tt0462036                      nm1940585            nm1940585
# 3       tt0835418                      nm0151540  nm0310087,nm0841532
# 4       tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ...           ...                            ...                  ...
# 146139  tt8999974                     nm10122357           nm10122357
# 146140  tt9001390                      nm6711477            nm6711477
# 146141  tt9001494          nm10123242,nm10123248                  NaN
# 146142  tt9004986                      nm4993825            nm4993825
# 146143  tt9010172                            NaN            nm8352242
#
# [146144 rows x 3 columns]

# %%
tn_movie_budgets_df = pd.read_csv('zippedData\\tn.movie_budgets.csv.gz')
tn_movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
tn_movie_budgets_df['production_budget'] = tn_movie_budgets_df['production_budget'].str.replace("$", "").str.replace(",","").astype('int')
#an attempt to manually clean the columns and turn the $"strings" into integers that I could use

# %%
tn_movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# 0          425000000   $760,507,625  $2,776,345,279
# 1          410600000   $241,063,875  $1,045,663,875
# 2          350000000    $42,762,350    $149,762,350
# 3          330600000   $459,005,868  $1,403,013,963
# 4          317000000   $620,181,382  $1,316,721,747

# %%
tn_movie_budgets_df['domestic_gross'] = tn_movie_budgets_df['domestic_gross'].str.replace("$", "").str.replace(",","").astype('int')

# %%
tn_movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross worldwide_gross
# 0          425000000       760507625  $2,776,345,279
# 1          410600000       241063875  $1,045,663,875
# 2          350000000        42762350    $149,762,350
# 3          330600000       459005868  $1,403,013,963
# 4          317000000       620181382  $1,316,721,747

# %%
tn_movie_budgets_df['domestic_profit'] = tn_movie_budgets_df['domestic_gross'] - tn_movie_budgets_df['production_budget']
tn_movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross worldwide_gross  domestic_profit
# 0          425000000       760507625  $2,776,345,279        335507625
# 1          410600000       241063875  $1,045,663,875       -169536125
# 2          350000000        42762350    $149,762,350       -307237650
# 3          330600000       459005868  $1,403,013,963        128405868
# 4          317000000       620181382  $1,316,721,747        303181382

# %%
tn_movie_budgets_df.sort_values(by= 'domestic_profit', ascending =False)
#ordered the indexes by profit, to help me give me some ideas in which factors lead to more profit
# Out:
#       id  release_date                                        movie  \
# 5      6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 41    42  Feb 16, 2018                                Black Panther
# 42    43  Dec 19, 1997                                      Titanic
# 3464  65  May 25, 1977                 Star Wars Ep. IV: A New Hope
# 33    34  Jun 12, 2015                               Jurassic World
# ...   ..           ...                                          ...
# 31    32  May 18, 2012                                   Battleship
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 12    13   Jul 2, 2013                              The Lone Ranger
# 13    14   Mar 9, 2012                                  John Carter
# 2      3   Jun 7, 2019                                 Dark Phoenix
#
#       production_budget  domestic_gross worldwide_gross  domestic_profit
# 5             306000000       936662225  $2,053,311,220        630662225
# ...

# %%
#joined_df = df1.join(df2, how='inner')

movie_studio_df = pd.read_csv('zippedData\\bom.movie_gross.csv.gz')
movie_studio_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
#initial attempts at combining the dataframes, 
#I used join instead of merge, which lead to many problems that 
#I did not realize until much later in the code

# %%
joined_df = tn_movie_budgets_df.join(movie_studio_df, how = 'inner', lsuffix= '_left', rsuffix= '_right')
joined_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross_left worldwide_gross  domestic_profit  \
# 0          425000000            760507625  $2,776,345,279        335507625
# 1          410600000            241063875  $1,045,663,875       -169536125
# 2          350000000             42762350    $149,762,350       -307237650
# 3          330600000            459005868  $1,403,013,963        128405868
# 4          317000000            620181382  $1,316,721,747        303181382
#
#                                          title studio  domestic_gross_right  \
# ...

# %%
#the dataframes were not joined on a key but instead joined together on the index, 
#which combined the data haphazardly and ultimately gave me random results

# %%
joined_df['studio']
# Out:
# 0               BV
# 1               BV
# 2               WB
# 3               WB
# 4             P/DW
#            ...
# 3382         Magn.
# 3383            FM
# 3384          Sony
# 3385    Synergetic
# 3386         Grav.
# Name: studio, Length: 3387, dtype: object

# %%
studio_df = (joined_df.groupby(['studio']))
#attempt to show the data with a groupby, not able to get the table printed however

# %%
studio_df.head()
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 3377  78  Oct 25, 2002                                        Frida
# 3378  79   Jul 5, 2012                       Katy Perry: Part of Me
# 3380  81  Sep 11, 1998                                     Rounders
# 3385  86  Sep 10, 1999                               Stir of Echoes
# 3386  87  Jan 13, 1995           Tales from the Crypt: Demon Knight
#
#       production_budget  domestic_gross_left worldwide_gross  domestic_profit  \
# ...

# %%
print(studio_df)

# %%
df2 = pd.read_csv('zippedData\\tmdb.movies.csv.gz')
df2.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
#joined_df = df1.join(df2, how='inner')
joined_df2 = joined_df.join(df2, how='inner', lsuffix= '_left', rsuffix= '_right')
#another erroneous join that I did not realize until later, tried comparing average_rating with domestic_gross

# %%
joined_df2.head()
# Out:
#    id_left release_date_left                                        movie  \
# 0        1      Dec 18, 2009                                       Avatar
# 1        2      May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2        3       Jun 7, 2019                                 Dark Phoenix
# 3        4       May 1, 2015                      Avengers: Age of Ultron
# 4        5      Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross_left worldwide_gross  domestic_profit  \
# 0          425000000            760507625  $2,776,345,279        335507625
# 1          410600000            241063875  $1,045,663,875       -169536125
# 2          350000000             42762350    $149,762,350       -307237650
# 3          330600000            459005868  $1,403,013,963        128405868
# 4          317000000            620181382  $1,316,721,747        303181382
#
# ...

# %%
x = joined_df2['vote_average']
y = joined_df2['domestic_gross_right']
plt.scatter(x,y, label = 'profit vs. rating', color = 'k')
#was able to plot the erroneous data

# %%
df3 = pd.read_csv('zippedData\\imdb.title.basics.csv.gz')

# %%
df3.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
df3.isna().sum()
#checking for NaN values to cut out or replace
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
df3_cleaned = df3.dropna()
#decided to drop the NaNs, not too many of them except for runtime_minutes and genres, which I was not using

# %%
df3_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112232 entries, 0 to 146139
# Data columns (total 6 columns):
# tconst             112232 non-null object
# primary_title      112232 non-null object
# original_title     112232 non-null object
# start_year         112232 non-null int64
# runtime_minutes    112232 non-null float64
# genres             112232 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
#joined_df = df1.join(df2, how='inner')
#joined_df2 = joined_df.join(df2, how='inner', lsuffix= '_left', rsuffix= '_right')
joined_df3 = joined_df.join(df3_cleaned, how='inner', lsuffix='_left', rsuffix='_right')
joined_df3.head()
#erroneous join to compare studio to profits and maybe ratings as well
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5   6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
#
#    production_budget  domestic_gross_left worldwide_gross  domestic_profit  \
# 0          425000000            760507625  $2,776,345,279        335507625
# 1          410600000            241063875  $1,045,663,875       -169536125
# 2          350000000             42762350    $149,762,350       -307237650
# 4          317000000            620181382  $1,316,721,747        303181382
# 5          306000000            936662225  $2,053,311,220        630662225
#
#                                          title studio  domestic_gross_right  \
# ...

# %%
df3_cleaned
# Out:
#            tconst                                      primary_title  \
# 0       tt0063540                                          Sunghursh
# 1       tt0066787                    One Day Before the Rainy Season
# 2       tt0069049                         The Other Side of the Wind
# 4       tt0100275                           The Wandering Soap Opera
# 5       tt0111414                                        A Thin Life
# ...           ...                                                ...
# 146134  tt9916160                                         Drømmeland
# 146135  tt9916170                                      The Rehearsal
# 146136  tt9916186  Illenau - die Geschichte einer ehemaligen Heil...
# 146137  tt9916190                                          Safeguard
# 146139  tt9916538                                Kuambil Lagi Hatiku
#
#                                            original_title  start_year  \
# ...

# %%
joined_df2
# Out:
#       id_left release_date_left                                        movie  \
# 0           1      Dec 18, 2009                                       Avatar
# 1           2      May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2           3       Jun 7, 2019                                 Dark Phoenix
# 3           4       May 1, 2015                      Avengers: Age of Ultron
# 4           5      Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...       ...               ...                                          ...
# 3382       83      Jun 15, 1979                                     Prophecy
# 3383       84      Jan 30, 2015                              Project Almanac
# 3384       85      May 14, 2010                                  Just Wright
# 3385       86      Sep 10, 1999                               Stir of Echoes
# 3386       87      Jan 13, 1995           Tales from the Crypt: Demon Knight
#
# ...

# %%
joined_df4 = df3_cleaned.join(joined_df2, how='inner', lsuffix= '_left', rsuffix= '_right')
joined_df4
# Out:
#           tconst                    primary_title         original_title_left  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5      tt0111414                      A Thin Life                 A Thin Life
# ...          ...                              ...                         ...
# 3374  tt10331574                         SOS Talk                    SOS Talk
# 3375  tt10331828                         16 Shots                    16 Shots
# 3376  tt10332008                 Makate Must Sell            Makate Must Sell
# 3383  tt10332120           Much Ado About Nothing      Much Ado About Nothing
# 3385  tt10332174                          Nothing                     Nothing
#
# ...

# %%
x = joined_df4['runtime_minutes']
y = joined_df4['vote_average']
plt.scatter(x,y)
#compared runtime_minutes vs vote_average using erroneous join

# %%
joined_df4['release_date_left'] = pd.to_datetime(joined_df4['release_date_left'])
#converting the date to a more usable format, though I realized there was a perfectly-good formatted date already later on

# %%
joined_df4
# Out:
#           tconst                    primary_title         original_title_left  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5      tt0111414                      A Thin Life                 A Thin Life
# ...          ...                              ...                         ...
# 3374  tt10331574                         SOS Talk                    SOS Talk
# 3375  tt10331828                         16 Shots                    16 Shots
# 3376  tt10332008                 Makate Must Sell            Makate Must Sell
# 3383  tt10332120           Much Ado About Nothing      Much Ado About Nothing
# 3385  tt10332174                          Nothing                     Nothing
#
# ...

# %%
joined_df4['month'] = joined_df['release_date'].str[:3]
joined_df4
#isoloating the month from the date to compare to see which month is most profitable on average
# Out:
#           tconst                    primary_title         original_title_left  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5      tt0111414                      A Thin Life                 A Thin Life
# ...          ...                              ...                         ...
# 3374  tt10331574                         SOS Talk                    SOS Talk
# 3375  tt10331828                         16 Shots                    16 Shots
# 3376  tt10332008                 Makate Must Sell            Makate Must Sell
# 3383  tt10332120           Much Ado About Nothing      Much Ado About Nothing
# 3385  tt10332174                          Nothing                     Nothing
#
# ...

# %%
joined_df4['year'] = joined_df4['release_date_right'].str[:3]
joined_df4
#isolating the year from the date to compare to profits
# Out:
#           tconst                    primary_title         original_title_left  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5      tt0111414                      A Thin Life                 A Thin Life
# ...          ...                              ...                         ...
# 3374  tt10331574                         SOS Talk                    SOS Talk
# 3375  tt10331828                         16 Shots                    16 Shots
# 3376  tt10332008                 Makate Must Sell            Makate Must Sell
# 3383  tt10332120           Much Ado About Nothing      Much Ado About Nothing
# 3385  tt10332174                          Nothing                     Nothing
#
# ...

# %%
len(joined_df4['month'])
len(joined_df2['domestic_profit'])
# Out:
# 3387

# %%
final_df = joined_df2.join(joined_df4, how='inner', lsuffix= '_left', rsuffix= '_right')
final_df
#combining date erroneously
# Out:
#       id_left_left release_date_left_left  \
# 0                1           Dec 18, 2009
# 1                2           May 20, 2011
# 2                3            Jun 7, 2019
# 4                5           Dec 15, 2017
# 5                6           Dec 18, 2015
# ...            ...                    ...
# 3374            75            Sep 1, 2006
# 3375            76           Dec 11, 1992
# 3376            77           Aug 12, 2016
# 3383            84           Jan 30, 2015
# 3385            86           Sep 10, 1999
#
#                                        movie_left  production_budget_left  \
# 0                                          Avatar               425000000
# 1     Pirates of the Caribbean: On Stranger Tides               410600000
# 2                                    Dark Phoenix               350000000
# 4               Star Wars Ep. VIII: The Last Jedi               317000000
# 5            Star Wars Ep. VII: The Force Awakens               306000000
# ...

# %%
x = final_df['month']
y = final_df['domestic_gross_left_left']
plt.barh(x,y)
#initally came up with this bar chart with the bad join, leading me to misinterpret my data at first
# Out:
# <BarContainer object of 1917 artists>

# %%
final_df['year_manual'] = final_df['release_date_right_right'].str[:4]

# %%
final_df
# Out:
#       id_left_left release_date_left_left  \
# 0                1           Dec 18, 2009
# 1                2           May 20, 2011
# 2                3            Jun 7, 2019
# 4                5           Dec 15, 2017
# 5                6           Dec 18, 2015
# ...            ...                    ...
# 3374            75            Sep 1, 2006
# 3375            76           Dec 11, 1992
# 3376            77           Aug 12, 2016
# 3383            84           Jan 30, 2015
# 3385            86           Sep 10, 1999
#
#                                        movie_left  production_budget_left  \
# 0                                          Avatar               425000000
# 1     Pirates of the Caribbean: On Stranger Tides               410600000
# 2                                    Dark Phoenix               350000000
# 4               Star Wars Ep. VIII: The Last Jedi               317000000
# 5            Star Wars Ep. VII: The Force Awakens               306000000
# ...

# %%
x = final_df['year_manual']
y = final_df['domestic_gross_left_left']
plt.bar(x,y)
#data showing year vs. profits
# Out:
# <BarContainer object of 1917 artists>

# %%
studio_df = pd.read_csv('zippedData\\bom.movie_gross.csv.gz')

# %%
studio_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
studio_joined_df = studio_df.join(final_df, how='inner')

# %%
studio_joined_df
# Out:
#                                                   title      studio  \
# 0                                           Toy Story 3          BV
# 1                            Alice in Wonderland (2010)          BV
# 2           Harry Potter and the Deathly Hallows Part 1          WB
# 4                                   Shrek Forever After        P/DW
# 5                            The Twilight Saga: Eclipse        Sum.
# ...                                                 ...         ...
# 3374                                         The Escape         IFC
# 3375  How Victor 'The Garlic' Took Alexey 'The Stud'...     CARUSEL
# 3376        Lou Andreas-Salomé, the Audacity to be Free         CLS
# 3383                        Edward II (2018 re-release)          FM
# 3385                                           The Swan  Synergetic
#
#       domestic_gross foreign_gross  year  id_left_left release_date_left_left  \
# ...

# %%
studio_joined_df['studio'] = studio_joined_df['studio'].fillna(value='No_studio')
#replacing NaNs in data with a usable entry

# %%
x = studio_joined_df['studio']
y = studio_joined_df['domestic_gross_left_left']

# %%
plt.figure(figsize=(20, 14))
plt.barh(x,y)
#attempt to see which studio was most profitable using bad join
# Out:
# <BarContainer object of 1917 artists>

# %%
studio_joined2 = studio_joined_df.groupby(['studio'])

# %%
print(studio_joined2)

# %%
x = studio_joined_df['studio']
y = studio_joined_df['vote_average_right']

# %%
plt.figure(figsize=(50, 40))
plt.barh(x,y)
#need to clean this data
# Out:
# <BarContainer object of 1917 artists>

# %%
#tn_movie_budgets_df.sort_values(by='budget_gross_diff', ascending=False)['movie'][:50]
final_df.sort_values(by='domestic_gross_left_left', ascending=False)[:50]
# Out:
#       id_left_left release_date_left_left  \
# 5                6           Dec 18, 2015
# 0                1           Dec 18, 2009
# 41              42           Feb 16, 2018
# 42              43           Dec 19, 1997
# 4                5           Dec 15, 2017
# 43              44           Jun 15, 2018
# 134             35           Mar 17, 2017
# 303              4           May 19, 1999
# 10              11           Jul 20, 2012
# 95              96            Mar 8, 2019
# 237             38           Nov 22, 2013
# 27              28            Jul 7, 2006
# 608              9           Jun 15, 1994
# 46              47           Jun 18, 2010
# 154             55            Jun 2, 2017
# 47              48            May 3, 2013
# 537             38           Mar 23, 2012
# 437             38           Dec 20, 2017
# 218             19            May 3, 2002
# 155             56           Nov 22, 2013
# 48              49            May 5, 2017
# ...

# %%
df1 = pd.read_csv('zippedData\\tmdb.movies.csv.gz')
df1
#the point in which I realized my dataframes were combined incorrectly
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
df2 = pd.read_csv('zippedData\\bom.movie_gross.csv.gz')
df2
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df2.set_index(['title'])
#setting index to merge
# Out:
#                                                  studio  domestic_gross  \
# title
# Toy Story 3                                          BV     415000000.0
# Alice in Wonderland (2010)                           BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# Inception                                            WB     292600000.0
# Shrek Forever After                                P/DW     238700000.0
# ...                                                 ...             ...
# The Quake                                         Magn.          6200.0
# Edward II (2018 re-release)                          FM          4800.0
# El Pacto                                           Sony          2500.0
# The Swan                                     Synergetic          2400.0
# An Actor Prepares                                 Grav.          1700.0
#
#                                             foreign_gross  year
# title
# ...

# %%
df1.set_index(['original_title'])
#setting index on second dataframe, did not realize I had to change the columns to be identical at first
# Out:
#                                               Unnamed: 0            genre_ids  \
# original_title
# Harry Potter and the Deathly Hallows: Part 1           0      [12, 14, 10751]
# How to Train Your Dragon                               1  [14, 12, 16, 10751]
# Iron Man 2                                             2        [12, 28, 878]
# Toy Story                                              3      [16, 35, 10751]
# Inception                                              4        [28, 878, 12]
# ...                                                  ...                  ...
# Laboratory Conditions                              26512             [27, 18]
# _EXHIBIT_84xxx_                                    26513             [18, 53]
# The Last One                                       26514         [14, 28, 12]
# Trailer Made                                       26515      [10751, 12, 28]
# The Church                                         26516             [53, 27]
#
# ...

# %%
d3 = pd.read_csv('zippedData\\imdb.title.ratings.csv.gz')
d3
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
d4 = pd.read_csv('zippedData\\imdb.title.basics.csv.gz')
d4
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
d3.set_index(d3['tconst'])
d3
#setting index to merge
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
d4.set_index(d4['tconst'])
#setting index to merge
# Out:
#               tconst                                primary_title  \
# tconst
# tt0063540  tt0063540                                    Sunghursh
# tt0066787  tt0066787              One Day Before the Rainy Season
# tt0069049  tt0069049                   The Other Side of the Wind
# tt0069204  tt0069204                              Sabse Bada Sukh
# tt0100275  tt0100275                     The Wandering Soap Opera
# ...              ...                                          ...
# tt9916538  tt9916538                          Kuambil Lagi Hatiku
# tt9916622  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# tt9916706  tt9916706                              Dankyavar Danka
# tt9916730  tt9916730                                       6 Gunn
# tt9916754  tt9916754               Chico Albuquerque - Revelações
#
#                                         original_title  start_year  \
# tconst
# tt0063540                                    Sunghursh        2013
# ...

# %%
joineddd = pd.merge(d4, d3, on = 'tconst')
joineddd
#merging to compare year vs. profits, month vs. profits, studio vs. profits
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
# ...

# %%
x = joineddd['start_year']
y = joineddd['averagerating']
plt.scatter(x,y)
#bar plot of year vs. rating (no correlation it seems)

# %%
profit_df = pd.read_csv('zippedData\\bom.movie_gross.csv.gz')
profit_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
profit_df.set_index('title')
# Out:
#                                                  studio  domestic_gross  \
# title
# Toy Story 3                                          BV     415000000.0
# Alice in Wonderland (2010)                           BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# Inception                                            WB     292600000.0
# Shrek Forever After                                P/DW     238700000.0
# ...                                                 ...             ...
# The Quake                                         Magn.          6200.0
# Edward II (2018 re-release)                          FM          4800.0
# El Pacto                                           Sony          2500.0
# The Swan                                     Synergetic          2400.0
# An Actor Prepares                                 Grav.          1700.0
#
#                                             foreign_gross  year
# title
# ...

# %%
joineddd.set_index('primary_title')
# Out:
#                                     tconst              original_title  \
# primary_title
# Sunghursh                        tt0063540                   Sunghursh
# One Day Before the Rainy Season  tt0066787             Ashad Ka Ek Din
# The Other Side of the Wind       tt0069049  The Other Side of the Wind
# Sabse Bada Sukh                  tt0069204             Sabse Bada Sukh
# The Wandering Soap Opera         tt0100275       La Telenovela Errante
# ...                                    ...                         ...
# Diabolik sono io                 tt9913084            Diabolik sono io
# Sokagin Çocuklari                tt9914286           Sokagin Çocuklari
# Albatross                        tt9914642                   Albatross
# La vida sense la Sara Amat       tt9914942  La vida sense la Sara Amat
# Drømmeland                       tt9916160                  Drømmeland
#
#                                  start_year  runtime_minutes  \
# primary_title
# ...

# %%
joinedddd = pd.merge(profit_df, joineddd, on=('title','primary_title'))
#bad merge, did not realize I had to set columns identical to each other
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-1b9e2537078f> in <module>
# ----> 1 joinedddd = pd.merge(profit_df, joineddd, on=('title','primary_title'))
#       2 #bad merge, did not realize I had to set columns identical to each other
#
# D:\asdf\jlkjkjconda\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# D:\asdf\jlkjkjconda\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     624             self.right_join_keys,
# ...

# %%
profit_df.drop_duplicates()
#attempted to drop duplicates to remedy problem, was not the problem of course

# %%
joineddd.drop_duplicates()

# %%
joineddd['title'] = joineddd['primary_title']
joineddd
#realized my mistake and added a new column named 'title' that was identical to 'primary_title'
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
# ...

# %%
joinedddd = pd.merge(profit_df, joineddd, on='title')
joinedddd
#it worked!
# Out:
#                            title  studio  domestic_gross foreign_gross  year  \
# 0                    Toy Story 3      BV     415000000.0     652000000  2010
# 1                      Inception      WB     292600000.0     535700000  2010
# 2            Shrek Forever After    P/DW     238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse    Sum.     300500000.0     398000000  2010
# 4                     Iron Man 2    Par.     312400000.0     311500000  2010
# ...                          ...     ...             ...           ...   ...
# 3022                    Souvenir  Strand         11400.0           NaN  2018
# 3023                    Souvenir  Strand         11400.0           NaN  2018
# 3024         Beauty and the Dogs   Osci.          8900.0           NaN  2018
# 3025                   The Quake   Magn.          6200.0           NaN  2018
# 3026           An Actor Prepares   Grav.          1700.0           NaN  2018
#
# ...

# %%
x = joinedddd['averagerating']
y = joinedddd['domestic_gross']
plt.scatter(x,y)
#plotting rating vs. gross
#

# %%
joinedddd['studio'] = joinedddd['studio'].fillna(value='No_studio')
#filling in NaNs in 'studio' column so that the values that can recognized appropriately

# %%
x = joinedddd['studio']
y = joinedddd['domestic_gross']
plt.barh(x,y)
#plotting studio vs. gross, bad chart and needs to be simplified
# Out:
# <BarContainer object of 3027 artists>

# %%
joinedddd.sort_values(by='domestic_gross', ascending=False)[:50]
#only choosing the most grossing movies

# %%
movies_df = pd.read_csv('zippedData\\tmdb.movies.csv.gz')
movies_df
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
budget_df = pd.read_csv('zippedData\\tn.movie_budgets.csv.gz')
budget_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
budget_df['title'] = budget_df['movie']
budget_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross  \
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
joined_2 = pd.merge(joinedddd, budget_df, on = 'title')
joined_2
#joining these two dataframes to compare date of release to profits
# Out:
#                            title studio  domestic_gross_x foreign_gross  year  \
# 0                    Toy Story 3     BV       415000000.0     652000000  2010
# 1                      Inception     WB       292600000.0     535700000  2010
# 2            Shrek Forever After   P/DW       238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse   Sum.       300500000.0     398000000  2010
# 4                     Iron Man 2   Par.       312400000.0     311500000  2010
# ...                          ...    ...               ...           ...   ...
# 1408                       Gotti     VE         4300000.0           NaN  2018
# 1409  Bilal: A New Breed of Hero     VE          491000.0       1700000  2018
# 1410                       Mandy    RLJ         1200000.0           NaN  2018
# 1411                       Mandy    RLJ         1200000.0           NaN  2018
# 1412                Lean on Pete    A24         1200000.0           NaN  2018
#
# ...

# %%
joined_2['month'] = joined_2['release_date'].str[:3]
joined_2
#creating a column for the month
# Out:
#                            title studio  domestic_gross_x foreign_gross  year  \
# 0                    Toy Story 3     BV       415000000.0     652000000  2010
# 1                      Inception     WB       292600000.0     535700000  2010
# 2            Shrek Forever After   P/DW       238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse   Sum.       300500000.0     398000000  2010
# 4                     Iron Man 2   Par.       312400000.0     311500000  2010
# ...                          ...    ...               ...           ...   ...
# 1408                       Gotti     VE         4300000.0           NaN  2018
# 1409  Bilal: A New Breed of Hero     VE          491000.0       1700000  2018
# 1410                       Mandy    RLJ         1200000.0           NaN  2018
# 1411                       Mandy    RLJ         1200000.0           NaN  2018
# 1412                Lean on Pete    A24         1200000.0           NaN  2018
#
# ...

# %%
x = joined_2['month']
y = joined_2['domestic_gross_x']
plt.barh(x,y)

# %%
x = joined_2['year']
y = joined_2['domestic_gross_x']
plt.barh(x,y)

# %%
joined_2['studio'] = joined_2['studio'].fillna(value = 'no_studio')
joined_2['studio']
# Out:
# 0         BV
# 1         WB
# 2       P/DW
# 3       Sum.
# 4       Par.
#         ...
# 1408      VE
# 1409      VE
# 1410     RLJ
# 1411     RLJ
# 1412     A24
# Name: studio, Length: 1413, dtype: object

# %%
joined_2['worldwide_gross'] = joined_2['worldwide_gross'].str.replace("$", "").str.replace(",","").astype('int')
joined_2
#realizing I needed to create a profits column myself as they only provided gross profits
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-ef4976c8c235> in <module>
# ----> 1 joined_2['worldwide_gross'] = joined_2['worldwide_gross'].str.replace("$", "").str.replace(",","").astype('int')
#       2 joined_2
#       3 #realizing I needed to create a profits column myself as they only provided gross profits
#
# D:\asdf\jlkjkjconda\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# D:\asdf\jlkjkjconda\envs\learn-env\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
joined_2
# Out:
#                            title studio  domestic_gross_x foreign_gross  year  \
# 0                    Toy Story 3     BV       415000000.0     652000000  2010
# 1                      Inception     WB       292600000.0     535700000  2010
# 2            Shrek Forever After   P/DW       238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse   Sum.       300500000.0     398000000  2010
# 4                     Iron Man 2   Par.       312400000.0     311500000  2010
# ...                          ...    ...               ...           ...   ...
# 1408                       Gotti     VE         4300000.0           NaN  2018
# 1409  Bilal: A New Breed of Hero     VE          491000.0       1700000  2018
# 1410                       Mandy    RLJ         1200000.0           NaN  2018
# 1411                       Mandy    RLJ         1200000.0           NaN  2018
# 1412                Lean on Pete    A24         1200000.0           NaN  2018
#
# ...

# %%
joined_2['production_budget'] = joined_2['production_budget'].str.replace("$", "").str.replace(",","").astype('int')
joined_2
# Out:
#                            title studio  domestic_gross_x foreign_gross  year  \
# 0                    Toy Story 3     BV       415000000.0     652000000  2010
# 1                      Inception     WB       292600000.0     535700000  2010
# 2            Shrek Forever After   P/DW       238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse   Sum.       300500000.0     398000000  2010
# 4                     Iron Man 2   Par.       312400000.0     311500000  2010
# ...                          ...    ...               ...           ...   ...
# 1408                       Gotti     VE         4300000.0           NaN  2018
# 1409  Bilal: A New Breed of Hero     VE          491000.0       1700000  2018
# 1410                       Mandy    RLJ         1200000.0           NaN  2018
# 1411                       Mandy    RLJ         1200000.0           NaN  2018
# 1412                Lean on Pete    A24         1200000.0           NaN  2018
#
# ...

# %%
joined_2['profits'] = joined_2['worldwide_gross'] - joined_2['production_budget']
joined_2
# Out:
#                            title studio  domestic_gross_x foreign_gross  year  \
# 0                    Toy Story 3     BV       415000000.0     652000000  2010
# 1                      Inception     WB       292600000.0     535700000  2010
# 2            Shrek Forever After   P/DW       238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse   Sum.       300500000.0     398000000  2010
# 4                     Iron Man 2   Par.       312400000.0     311500000  2010
# ...                          ...    ...               ...           ...   ...
# 1408                       Gotti     VE         4300000.0           NaN  2018
# 1409  Bilal: A New Breed of Hero     VE          491000.0       1700000  2018
# 1410                       Mandy    RLJ         1200000.0           NaN  2018
# 1411                       Mandy    RLJ         1200000.0           NaN  2018
# 1412                Lean on Pete    A24         1200000.0           NaN  2018
#
# ...

# %%
#plotting month vs. profits
plt.figure(figsize=(15,9))
x = joined_2['month']
y = joined_2['profits']
plt.bar(x,y)

plt.xlabel('Month')
plt.ylabel('Profits')
plt.title("Month vs. Profits")
# Out:
# Text(0.5, 1.0, 'Month vs. Profits')

# %%
#plotting studio vs. profits
plt.figure(figsize=(16, 12))
x = joined_2['studio']
y = joined_2['profits']
plt.barh(x,y)

plt.xlabel('Studio')
plt.ylabel('Profits')
plt.title("Studios vs. Profits")
# Out:
# Text(0.5, 1.0, 'Studios vs. Profits')

# %%
#need to clean data, took only the top 100 best-performing movie in terms of profits
final = joined_2.sort_values(by='profits', ascending=False)[:100]
final
# Out:
#                                    title studio  domestic_gross_x  \
# 1302              Avengers: Infinity War     BV       678800000.0
# 824                       Jurassic World   Uni.       652300000.0
# 825                            Furious 7   Uni.       353000000.0
# 1303                       Black Panther     BV       700100000.0
# 1304      Jurassic World: Fallen Kingdom   Uni.       417700000.0
# ...                                  ...    ...               ...
# 187   Sherlock Holmes: A Game of Shadows     WB       186800000.0
# 1017                          La La Land   LG/S       151100000.0
# 837                         The Revenant    Fox       183600000.0
# 836                         The Revenant    Fox       183600000.0
# 188                                  Rio    Fox       143600000.0
#
#      foreign_gross  year     tconst                       primary_title  \
# 1302       1,369.5  2018  tt4154756              Avengers: Infinity War
# ...

# %%
plt.figure(figsize=(16, 12))
x = final['studio']
y = final['profits']
plt.barh(x,y)

plt.xlabel('Studio')
plt.ylabel('Profits')
plt.title("Studios vs. Profits")
# Out:
# Text(0.5, 1.0, 'Studios vs. Profits')

# %%
#plotting year vs profits to see potential growth in the industry moving fowards
plt.figure(figsize=(15,9))
x = joined_2['year']
y = joined_2['domestic_gross_x']

plt.barh(x,y)

plt.xlabel('Year')
plt.ylabel('Profits')
plt.title("Year vs. Profits")
# Out:
# Text(0.5, 1.0, 'Year vs. Profits')

# %%
plt.figure(figsize=(15,9))
x = joined_2['averagerating']
y = joined_2['profits']
#correlations in that better grossing movies tended to also do better with audiences
plt.scatter(x,y, label = "Ratings vs. Profits")

plt.xlabel('Average Rating')
plt.ylabel('Profits')
plt.title("Ratings vs. Profits")
# Out:
# Text(0.5, 1.0, 'Ratings vs. Profits')
